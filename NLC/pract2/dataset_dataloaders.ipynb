# %%
#Loading a Built-in Dataset (FashionMNIST)

import torch
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt

# Download and load the training dataset
training_data = datasets.FashionMNIST(
    root="data",               # directory to store data
    train=True,                # load training set
    download=True,             # download if not already present
    transform=ToTensor()       # convert PIL image to tensor
)

# Download and load the test dataset
test_data = datasets.FashionMNIST(
    root="data",
    train=False,               # load test set
    download=True,
    transform=ToTensor()
)
# Out:
# 100%|██████████| 26.4M/26.4M [00:17<00:00, 1.51MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 84.1kB/s]
# 100%|██████████| 4.42M/4.42M [03:16<00:00, 22.5kB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 5.15MB/s]

# %% [markdown]
# Visualizing Dataset Samples

# %%
# Mapping of numeric labels to class names
labels_map = {
    0: "T-Shirt",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle Boot",
}

# Display 9 random images with labels from the training data
figure = plt.figure(figsize=(8, 8))
cols, rows = 3, 3

for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(training_data), size=(1,)).item()
    img, label = training_data[sample_idx]
    figure.add_subplot(rows, cols, i)
    plt.title(labels_map[label])
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # Iterate through the DataLoader
#       2 # Display image and label.
# ----> 3 train_features, train_labels = next(iter(train_dataloader))
#       4 print(f"Feature batch shape: {train_features.size()}")
#       5 print(f"Labels batch shape: {train_labels.size()}")
#
# NameError: name 'train_dataloader' is not defined
